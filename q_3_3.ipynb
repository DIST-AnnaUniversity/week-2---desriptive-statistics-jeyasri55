# %%
import pandas as pd
import numpy
import io
df = pd.read_csv('/Daily_Rainfall_data_from_National_Remote_Sensing_Centre_Agency_during_October_2022.csv')
df1=df.tail(35)
df2=df1.dropna()
final = pd.DataFrame(df2.Avg_rainfall)
print(final)
final.boxplot(figsize=(5,5),grid=False)
q3,q1 = numpy.percentile(final,[75,25])
iqr = q3 - q1
lf=q1-1.5*iqr
uf=q3+1.5*iqr
print("Lower fence ",lf)
print("Upper fence ",uf)
final.describe()
# Out:
#        Avg_rainfall
# 19024      0.004033
# 19026      0.000151
# 19028      0.075893
# 19029      2.124929
# 19030      8.068375
# 19032     11.689524
# 19033     10.815236
# 19034     11.660267
# 19035     11.481102
# 19036      9.390205
# 19037      5.502119
# 19038      0.474305
# 19039      1.419904
# 19041      0.070861
# 19042      0.002213
# 19043     24.423169
# 19044      9.739172
# 19045      7.312805
# 19046      3.123500
# 19047      0.334683
# 19048      0.023277
# 19049      0.000003
# 19050      0.234520
# 19051      0.001928
# 19052      0.001192
# 19054      0.019834
# 19055      0.364070
# 19056      0.604070
# Lower fence  -12.542209372512499
# Upper fence  20.9634580779875
#        Avg_rainfall
# count     28.000000
# mean       4.248619
# std        5.967588
# min        0.000003
# 25%        0.022416
# 50%        0.539187
# 75%        8.398833
# max       24.423169

# %% [markdown]
# Yes, There is an outlier 24.423169 .
#
# Since the Lower and Upper fenc values lies between  -12.542209372512499 and 20.9634580779875
